# %% [markdown]
# ##1. Load Packages

# %%
import tweepy
import time
import pandas as pd
import re
import collections

consumer_key ='pX1VF2Mp5FicThnpyWmP7GyH3'
consumer_secret = 'zuesUN6OPburvzMssJivbGNwgjfSj3vNCaJ4hbH9WrZlbwhweM'
access_token = '440434796-7YLC6Tnpv8beLCjVhHXLxa9XLxC1aoYI4iP2XrNy'
access_token_secret = '0VzybqOTxPoUQLeuAdmsdAmOtCCyDdPb8wIht12Vg2ukP'

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

# %% [markdown]
# ##Load testing file

# %%
import pickle
#TO WRITE
#with open("fallout4.txt", 'wb') as f:
#    pickle.dump(data, f)
#TO READ
with open("fallout4.txt", 'rb') as f:
    data = pickle.load(f)

# %% [markdown]
# ##2. Load Tweets

# %%
trend = tweepy.Cursor(api.search, q='fallout4', since='2015-05-01', until='2015-06-03').items()
print "ready"
# Out:
# ready

# %%
data = []

# %%
for i in trend:
    data.append(i)
# Out:
# ---------------------------------------------------------------------------
# TweepError                                Traceback (most recent call last)
# <ipython-input-24-bd6babca9136> in <module>()
# ----> 1 for i in trend:
#       2     data.append(i)
#
# /home/honu/anaconda/lib/python2.7/site-packages/tweepy/cursor.pyc in next(self)
#     195         if self.current_page is None or self.page_index == len(self.current_page) - 1:
#     196             # Reached end of current page, get the next page...
# --> 197             self.current_page = self.page_iterator.next()
#     198             self.page_index = -1
#     199         self.page_index += 1
#
# /home/honu/anaconda/lib/python2.7/site-packages/tweepy/cursor.pyc in next(self)
#     106
#     107         if self.index >= len(self.results) - 1:
# --> 108             data = self.method(max_id=self.max_id, parser=RawParser(), *self.args, **self.kargs)
#     109
#     110             if hasattr(self.method, '__self__'):
#
# /home/honu/anaconda/lib/python2.7/site-packages/tweepy/binder.pyc in _call(*args, **kwargs)
#     237             return method
#     238         else:
# --> 239             return method.execute()
#     240
#     241     # Set pagination mode
#
# /home/honu/anaconda/lib/python2.7/site-packages/tweepy/binder.pyc in execute(self)
#     221                 except Exception:
#     222                     error_msg = "Twitter error response: status code = %s" % resp.status_code
# --> 223                 raise TweepError(error_msg, resp)
#     224
#     225             # Parse the response payload
#
# TweepError: {"errors":[{"message":"Rate limit exceeded","code":88}]}

# %%
len(data)
# Out:
# 3450

# %%
data[545].lang
# Out:
# u'en'

# %% [markdown]
# ##Get #hashtags and @references

# %%
data_text = ' '.join([data[i].text.lower() for i in xrange(len(data))]).encode('utf-8')

# %%
#hashtags = re.findall(r'\b#\w+', data_text)
#at_user = re.findall(r'\b@\w+', data_text)
 
hashtags = re.findall(r'#\w*', data_text)
at_user = re.findall(r'@\w*', data_text)

# %%
hashtags_frequency = collections.Counter(hashtags)
at_user_frequency = collections.Counter(at_user)

# %% [markdown]
# ## Build a dataframe

# %%
def load_entry(entry):
    #row = pd.DataFrame(columns= ["created_at", "user", "favs", "rt", "lang", "text", "user_pic"])
    row = pd.Series()
    row["created_at"] = str(entry.created_at)
    row["user"] = entry.user.screen_name.encode("utf-8")
    row["favs"] = entry.favorite_count
    row["rt"] = entry.retweet_count
    row["lang"] = entry.lang.encode("utf-8")
    row["time_zone"] = get_time_zone(entry)
    row["text"] = entry.text.encode("utf-8")
    row["user_pic"] = entry.user.profile_image_url.encode("utf-8")
    
    return row

def get_time_zone(entry):
    if entry._json["user"]["time_zone"] == None:
        return "N/A"
    else:
        return entry._json["user"]["time_zone"].encode("utf-8")

# %%
df = pd.DataFrame(columns= ["created_at", "user", "favs", "rt", "lang", "time_zone", "text", "user_pic"])
for entry in data:
    df = df.append(load_entry(entry), ignore_index = True)

# %% [markdown]
# ##Preparing the JSON output

# %%
output = {}

# %%
data[896].text
# Out:
# u"War. War never changes. Well, except the numeral. And technology. And... fuck it, I'm excited! #Fallout4 http://t.co/FfBOtZtbbi"

# %%
top_hashtags = hashtags_frequency.most_common(10)
top_users = at_user_frequency.most_common(10)
most_fav = df[df["favs"] == df["favs"].max()].head(1)
#most_rt = df[df["favs"] == df["favs"].max()].head(1)
most_rt = data[df[df["rt"] == df["rt"].max()].head(1).index[0]].retweeted_status
time_zones = collections.Counter(df["time_zone"]).most_common(25)

output["len"] = len(df)
output["lang"] = [[df["lang"].value_counts().head().index[i], df["lang"].value_counts().head().values[i]] for i in xrange(5)]
output["time_zones"] = [[entry[0],[1]] for entry in time_zones]
output["hashtags"] = [[top_hashtags[i][0], top_hashtags[i][1]] for i in xrange(10)]
output["users"] = [[top_users[i][0], top_users[i][1]] for i in xrange(10)]
output["most_fav"] = {"user": most_fav["user"], "user_pic": most_fav["user_pic"], "text": most_fav["text"], "favs": most_fav["favs"], "rt": most_fav["rt"], "created_at": most_fav["created_at"]}
output["most_rt"] = {"user": most_rt.user.screen_name.encode("utf-8"), "user_id": most_rt.user.id,"user_pic": most_rt.user.profile_image_url.encode("utf-8"), "text": most_rt.text.encode("utf-8"), "tweet_id": most_rt.id, "favs": most_rt.favorite_count, "rt": most_rt.retweet_count, "created_at": str(most_rt.created_at)}
output["text"] = data_text

# %%
output
# Out:
# {'hashtags': [['#fallout4', 2899],
#   ['#pleasestandby', 541],
#   ['#bethesda', 113],
#   ['#fallout', 103],
#   ['#fallout4confirmed', 102],
#   ['#hype', 29],
#   ['#e32015', 27],
#   ['#', 25],
#   ['#blatter', 23],
#   ['#hypetrain', 20]],
#  'lang': [['en', 2573], ['ja', 445], ['und', 178], ['es', 92], ['de', 49]],
#  'len': 3450,
#  'most_fav': {'created_at': 896    2015-06-02 22:58:33
#   Name: created_at, dtype: object, 'favs': 896    239
#   Name: favs, dtype: float64, 'rt': 896    152
#   Name: rt, dtype: float64, 'text': 896    War. War never changes. Well, except the numer...
#   Name: text, dtype: object, 'user': 896    ChrisAvellone
#   Name: user, dtype: object, 'user_pic': 896    http://pbs.twimg.com/profile_images/3732919436...
#   Name: user_pic, dtype: object},
#  'most_rt': {'created_at': '2015-06-02 15:22:58',
#   'favs': 266,
#   'rt': 278,
#   'text': 'FALLOUT 4! FALLOUT 4! FALLOUT 4! FALLOUT 4! FALLOUT 4! FALLOUT 4! FALLOUT 4! FALLOUT 4! FALLOUT 4! #Fallout4 http://t.co/YUotbQfbYD',
#   'tweet_id': 605756497356713986,
#   'user': 'americo76',
#   'user_id': 37868094,
#   'user_pic': 'http://pbs.twimg.com/profile_images/605700980303228928/gy2RTZON_normal.jpg'},
conectamos en directo con la redacci\xc3\xb3n de hobby consolas. http://t.co/qupxq1tukc #pleasestandby  #fallout4 http://t.co/\xe2\x80\xa6 it\'s counting down to 10am est. #thingstoremember #fallout4 video games weekly with @andrew_reiner is next on @kfan1003. we\'ll breakdown #fallout4, #xcom2, and #splatoon rt @miekstaon: reminder: physics &amp; engineering advances not only make better game systems but also make an actual #fallout4 scenario more l\xe2\x80\xa6 rt @moominrook: all aboard the fallout hype train! #pleasestandby #fallout4 http://t.co/tjczovrwyh all aboard the hype train. #fallout4 #pleasestandby http://t.co/tjftp2ew4m  #fallout4 rt @nerdistdotcom: please stand by for a #fallout4 announcement from @bethesdastudios tomorrow! http://t.co/v2oo5brrre by @sam3214 http://t\xe2\x80\xa6 reminder: physics &amp; engineering advances not only make better game systems but a ...
#  'time_zones': [['N/A', [1]],
#   ['Eastern Time (US & Canada)', [1]],
#   ['Central Time (US & Canada)', [1]],
#   ['Pacific Time (US & Canada)', [1]],
#   ['London', [1]],
#   ['Tokyo', [1]],
#   ['Amsterdam', [1]],
#   ['Irkutsk', [1]],
#   ['Atlantic Time (Canada)', [1]],
#   ['Arizona', [1]],
#   ['Hawaii', [1]],
#   ['Athens', [1]],
#   ['Mountain Time (US & Canada)', [1]],
#   ['Dublin', [1]],
#   ['Casablanca', [1]],
#   ['Seoul', [1]],
#   ['Madrid', [1]],
#   ['Berlin', [1]],
#   ['Quito', [1]],
#   ['Brisbane', [1]],
#   ['Osaka', [1]],
#   ['Caracas', [1]],
#   ['Buenos Aires', [1]],
#   ['Edinburgh', [1]],
#   ['Brasilia', [1]]],
#  'users': [['@bethesdastudios', 204],
#   ['@falloutlsd', 109],
#   ['@chrisavellone', 94],
#   ['@bethblog', 74],
#   ['@emmylol1', 69],
#   ['@americo76', 64],
#   ['@fo4news', 58],
#   ['@4allout', 48],
#   ['@sam3214', 39],
#   ['@nerdistdotcom', 38]]}

# %%
#print df["lang"].unique()
#print df["lang"].value_counts().head().index[1]
#output
df[df["favs"] == df["favs"].max()].head(1)["created_at"]
# Out:
# 896    2015-06-02 22:58:33
# Name: created_at, dtype: object

# %%
print hashtags_frequency.most_common(10)
print at_user_frequency.most_common(10)
# Out:
# [('#fallout4', 2899), ('#pleasestandby', 541), ('#bethesda', 113), ('#fallout', 103), ('#fallout4confirmed', 102), ('#hype', 29), ('#e32015', 27), ('#', 25), ('#blatter', 23), ('#hypetrain', 20)]
# [('@bethesdastudios', 204), ('@falloutlsd', 109), ('@chrisavellone', 94), ('@bethblog', 74), ('@emmylol1', 69), ('@americo76', 64), ('@fo4news', 58), ('@4allout', 48), ('@sam3214', 39), ('@nerdistdotcom', 38)]

# %%
timeline = api.user_timeline()

# %%
timeline[13].user.profile_image_url
# Out:
# u'http://pbs.twimg.com/profile_images/560871129364332544/MRAaJoQM_normal.jpeg'

# %%
data[0].user.screen_name.encode("utf-8")
# Out:
# 'thesamz9'

# %%
df["text"][9]
# Out:
# '#PleaseStandBy #Fallout4 14 hours !! !! !! !!'

# %%
print hashtags.count("#pleasestandby")
print hashtags.count("#fallout4")
print hashtags.count("#fallout")
print hashtags.count("#bethesda")
print hashtags.count("#e3")
# Out:
# 541
# 2899
# 103
# 113
# 19

# %%
#print df[(df["favs"] == df["favs"].max())]
len(df[(df["rt"] == df["rt"].max())])
df[(df["rt"] == df["rt"].max())].head(2)
# Out:
#              created_at       user  favs   rt lang  \
# 3   2015-06-02 23:59:49   CobaltK9     0  278   en
# 58  2015-06-02 23:54:40  EpicWin64     0  278   en
#
#                      time_zone  \
# 3                        Perth
# 58  Central Time (US & Canada)
#
#                                                  text  \
# 3   RT @americo76: FALLOUT 4! FALLOUT 4! FALLOUT 4...
# 58  RT @americo76: FALLOUT 4! FALLOUT 4! FALLOUT 4...
#
#                                              user_pic
# 3   http://pbs.twimg.com/profile_images/5618826692...
# 58  http://pbs.twimg.com/profile_images/3788000008...

# %%
print data[9].entities["hashtags"]
# Out:
# [{u'indices': [0, 14], u'text': u'PleaseStandBy'}, {u'indices': [15, 24], u'text': u'Fallout4'}]

# %%
#from datetime import datetime
#datetime.strptime(str(data[0].created_at), "%Y-%m-%d %H:%M:%S")
# Out:
# datetime.datetime(2015, 6, 2, 23, 59, 54)

# %%
#str(data[0].created_at)
# Out:
# str

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt
from wordcloud import WordCloud

wordcloud = WordCloud(font_path="/usr/share/fonts/OTF/SyrCOMUrhoy.otf").generate(data_text)
#wordcloud
#font_path="/usr/share/fonts/OTF/SyrCOMUrhoy.otf"
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
locations = []
for i in xrange(len(data)):
    locations.append(get_time_zone(data[i]))

# %%
import sys
print sys.getsizeof(data_text)
print sys.getsizeof(data_text.split(" "))
print sys.getsizeof(str(data_text.split(" ")))
# Out:
# 324293
# 304584
# 546301

# %%
data[3]._json["text"]
# Out:
# u'RT @americo76: FALLOUT 4! FALLOUT 4! FALLOUT 4! FALLOUT 4! FALLOUT 4! FALLOUT 4! FALLOUT 4! FALLOUT 4! FALLOUT 4! #Fallout4 http://t.co/YUo\u2026'

# %%
#data[896].entities["user_mentions"][0]["screen_name"].encode("utf-8")
#print data[3].user.screen_name.encode("utf-8") + "/status/" + str(data[3]._json["id"])
#df.ix[3,:].created_at
print data[most_fav.index[0]].entities["user_mentions"][0]["screen_name"] + " /// " +  data[most_fav.index[0]].user.screen_name
print df["user_pic"][3]
print data[3].entities["profile_image_url_http"]
most_fav
# Out:
# americo76 /// CobaltK9
# http://pbs.twimg.com/profile_images/561882669244366849/RH4tzny1_normal.png
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-283-8c0e0c7a0f4d> in <module>()
#       4 print data[most_fav.index[0]].entities["user_mentions"][0]["screen_name"] + " /// " +  data[most_fav.index[0]].user.screen_name
#       5 print df["user_pic"][3]
# ----> 6 print data[3].entities["profile_image_url_http"]
#       7 most_fav
#
# KeyError: 'profile_image_url_http'

# %%
for i in xrange(100):
    try:
        print data[i].retweet_count
        #if str(data[i].entities["user_mentions"][0]["screen_name"]) == str(data[i].user.screen_name):
        #    print "TRUE"
        #else:
        #    print "FALSE"
        print data[i].entities["user_mentions"][0]["screen_name"] + " /// " + data[i].user.screen_name
        print data[i].text
    except:
        print "N/A"
# Out:
# 57
# NerdistDotCom /// thesamz9
# RT @NerdistDotCom: Please stand by for a #Fallout4 Announcement from @BethesdaStudios tomorrow! http://t.co/V2oO5BrRre by @sam3214 http://t…
# 0
# N/A
# 11
# Xtreme_Gaming /// Brandonaleman8
# RT @Xtreme_Gaming: I know where I will be waiting #Fallout4 http://t.co/AGzG8pygVF http://t.co/rZwmJrElmv
# 278
# americo76 /// CobaltK9
# RT @americo76: FALLOUT 4! FALLOUT 4! FALLOUT 4! FALLOUT 4! FALLOUT 4! FALLOUT 4! FALLOUT 4! FALLOUT 4! FALLOUT 4
# NerdistDotCom /// badjujucat
# RT @NerdistDotCom: Please stand by for a #Fallout4 Announcement from @BethesdaStudios tomorrow! http://t.co/V2oO5BrRre by @sam3214 http://t…
# 1
# N/A
# 0
# N/A
# 0
# N/A
# 0
# N/A
# 0
# N/A
# 0
# N/A
# 0
# N/A
# 2
# Basement_Gamer_ /// ncrambassador
# RT @Basement_Gamer_: Less than a day away
# #PleaseStandBy #Fallout4 http://t.co/4Rui1zVN9z
# 0
# N/A
# 104
# falloutlsd /// ibbz1234
# RT @falloutlsd: IT'S FINALLY COMING #Fallout4 #PleaseStandBy http://t.co/q4qNTfnqxm
# 0
# N/A
# 6
# Yokijirou /// CVAnimation
# RT @Yokijirou: Hopes for #Fallout4: Release (tomorrow) this year. I believe in you @BethesdaStudios make my #E32015 dreams come true http:/…
# 0
# N/A
# 0
# N/A
# 0
# N/A
# 0
# Bethblog /// playmkrdigital
# Finally, @Bethblog teases #Fallout4 announcement with countdown clock on their official website http://t.co/WrOzyYWnUx #Bethesda #gamingnews
# 0
# N/A
# 107
# Emmylol1 /// xXKintorinXx
# RT @Emmylol1: All aboard the #Fallout4 hype train! http://t.co/1duYyG4eIg
# 0
# N/A
# 0
# N/A
# 0
# N/A
# 1
# HeatherZWeather /// Tyu248
# RT @HeatherZWeather: Me watching the #Fallout4 countdown ticker like: http://t.co/6y9cCJnzmL
# 152
# ChrisAvellone /// mx7070
# RT @ChrisAvellone: War. War never changes. Well, except the numeral. And technology. And... fuck it, I'm excited! #Fallout4 http://t.co/FfB…
# 278
# americo76 /// EpicWin64
# RT @americo76: FALLOUT 4! FALLOUT 4! FALLOUT 4! FALLOUT 4! FALLOUT 4! FALLOUT 4! FALLOUT 4! FALLOUT 4! FALLOUT 4! #Fallout4 http://t.co/YUo…
# 12
# stillgray /// TehAddiction2
# RT @stillgray: I just received this in an e-mail, which was titled "Fallout 4.1". #Fallout4 http://t.co/72qmt6L3fx
# 0
# N/A
# 0
# N/A
# 81
# AnnoyedGamer /// cwtkw
# RT @AnnoyedGamer: Breaking news: #SeppBlatter resigns, says he is too excited by #Fallout4 to take more bribes.
# 3
# gpb_17 /// keigo753
# RT @gpb_17: Fallout4かと思いきやFallout3 リマスターだった時のファンの反応 http://t.co/mYCbxixWEF
# 0
# BethesdaStudios /// pearljam2006
# I'll be seriously let down if the so called #Fallout4 announcement is actually #Fallout3 remastered @BethesdaStudios #PS4
# 12
# stillgray /// brian_carnell
# RT @stillgray: I just received this in an e-mail, which was titled "Fallout 4.1". #Fallout4 http://t.co/72qmt6L3fx
# 3
# FO4News /// SG_OB3Y
# RT @FO4News: Public announcement found in http://t.co/YoBWIsfqTZ source code - #Fallout4 http://t.co/ABFlXgEPBT
# 1
# N/A
# 152
# ChrisAvellone /// PenettYo
# RT @ChrisAvellone: War. War never changes. Well, except the numeral. And technology. And... fuck it, I'm excited! #Fallout4 http://t.co/FfB…
# 1
# N/A
# 45
# _dpiddy /// cwtkw
# RT @_dpiddy: #Fallout4 has me like... http://t.co/TzawsgMhms
# 1
# GeekBomb /// MissJonesAndI
# RT @GeekBomb: If the #fallout4 announcement was in fact a card game I would be into it if it was anything like Gwent. Tunnel Snake deck! - …
# 12
# N/A
# 0
# N/A
# 0
# N/A
# 45
# _dpiddy /// matt_tato_nana
# RT @_dpiddy: #Fallout4 has me like... http://t.co/TzawsgMhms
# 3
# N/A
# 0
# N/A
# 1
# scifiedcom /// aaronschey
# RT @scifiedcom: The Fallout 4 Announcement Has Begun! http://t.co/SamhyRJAaM
# 14
# Fallout4Dads /// RetroWaveDave
# RT @Fallout4Dads: Welcome aboard! The #Fallout4 #hypetrain has left the station! http://t.co/hnxO96hoK5
# 1
# Haas_Kicker /// Stofnn_BRont
# RT @Haas_Kicker: Cnt wait for fallout4
# 0
# Bethblog /// jonsaidstuff
# The most awaited countdown in gaming history is officially underway...
# #Fallout4 @Bethblog http://t.co/DOhbuKq2BE
# 41
# falloutlsd /// cwtkw
# RT @falloutlsd: The internet today #Fallout4 #PleaseStandBy http://t.co/OhQKzri2ZN
# 83
# ItsFlareWare /// beatdjam
# RT @ItsFlareWare: TFW you made a tweet about #Fallout4 less than 24 hours ago. http://t.co/9KNpPcbvCp
# 0
# N/A
# 0
# G27Status /// OverholtTyler
# OMG OMG NO WAY FALLOUT4!!!!! HELPPPPPP @G27Status I NEED TO HUG AND KISS SOMEONE!!!
# 1
# N/A
# 0
# N/A
# 0
# N/A
# 29
# DigitalAbdullah /// Brandonaleman8
# RT @DigitalAbdullah: Houston we have a problem. #Fallout4 #PleaseStandBy http://t.co/4j28NgZVh4
# 14
# Fallout4Dads /// thornes70
# RT @Fallout4Dads: Welcome aboard! The #Fallout4 #hypetrain has left the station! http://t.co/hnxO96hoK5
# 0
# N/A
# 0
# N/A
# 0
# N/A
# 0
# N/A
# 152
# ChrisAvellone /// DeftDodger
# RT @ChrisAvellone: War. War never changes. Well, except the numeral. And technology. And... fuck it, I'm excited! #Fallout4 http://t.co/FfB…
# 0
# BethesdaStudios /// ishouldbecoding
# Something is stirring at @BethesdaStudios http://t.co/MOoZdUFs9d #Fallout4 @LoreHound
# 33
# pcworld /// AdamH456
# RT @pcworld: If this means what we think it means, #Fallout4 is coming YUSSsss http://t.co/5GZz2cyjqw @haydencd #FALLOUT4CONFIRMED http://t…
# 0
# G27Status /// Boomspike
# @G27Status first thing I thought this morning was "how's Matty gonna react to this?" #ChooChoo #Fallout4 #PleaseStandBy
# 278
# americo76 /// CheesyFeline
# RT @americo76: FALLOUT 4! FALLOUT 4! FALLOUT 4! FALLOUT 4! FALLOUT 4! FALLOUT 4! FALLOUT 4! FALLOUT 4! FALLOUT 4! #Fallout4 http://t.co/YUo…

# %%
data[3].retweeted_status.created_at
# Out:
# datetime.datetime(2015, 6, 2, 15, 22, 58)

# %%
print data[3].retweeted_status.user.profile_image_url.encode("utf-8")
print data[3].retweeted_status.user.screen_name.encode("utf-8")
print "http://twitter.com/" + data[3].retweeted_status.user.id_str + "/status/" + data[3].retweeted_status.id_str
print data[3].retweeted_status.id
print data[3].retweeted_status.text.encode("utf-8")
print data[3].retweeted_status.favorite_count
print data[3].retweeted_status.retweet_count
print str(data[3].retweeted_status.created_at)
# Out:
# http://pbs.twimg.com/profile_images/605700980303228928/gy2RTZON_normal.jpg
# americo76
# http://twitter.com/37868094/status/605756497356713986
# 605756497356713986
# FALLOUT 4! FALLOUT 4! FALLOUT 4! FALLOUT 4! FALLOUT 4! FALLOUT 4! FALLOUT 4! FALLOUT 4! FALLOUT 4! #Fallout4 http://t.co/YUotbQfbYD
# 266
# 278
# 2015-06-02 15:22:58
